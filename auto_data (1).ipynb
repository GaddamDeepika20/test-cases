# %% [markdown]
# # import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # View and call dataset to environment ?

# %%
data=pd.read_csv("C:/Users/Admin/Downloads/auto_data.csv")
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Find info , top 5 records , bottom 5 records ?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.tail(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %% [markdown]
# # Represent Corelation between variables ?

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True,linewidths=0.5)
plt.title("correlation heatmap")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3728\1153142636.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,linewidths=0.5)

# %% [markdown]
# # plot different kinds of graphs for mean value represetation ?

# %%
mean_values=data.mean()
mean_values
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3728\1360917248.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values=data.mean()
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# origin             1.572864
# dtype: float64

# %% [markdown]
# ### Bar plot for mpgnby origin

# %%
mean_mpg_by_origin=data.groupby('origin')['mpg'].mean()

# %%
mean_mpg_by_origin.plot(kind='bar')
plt.title=("mean mpg by origin")
plt.xlabel("orogin")
plt.ylabel("mean mpg ")
plt.show()

# %% [markdown]
# ### Histogram for mean weight

# %%
mean_horsepower=data['weight'].mean()
plt.hist(data['weight'],bins=20,alpha=0.5,color='b',label='weight')
plt.axvline(mean_horsepower,color='r',linestyle='dashed',linewidth=2,label="mean weight")
plt.xlabel('weight')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### grouping the data by model_year and calculating the mean of the specified attributes

# %%
mean_values=data.groupby('model_year')[['mpg','cylinders','displacement','horsepower','weight','acceleration']].mean()
mean_values.plot(kind='bar',subplots=True , layout=(2,3),figsize=(15,8),title="mean values by model year")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3728\3338150968.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_values=data.groupby('model_year')[['mpg','cylinders','displacement','horsepower','weight','acceleration']].mean()

# %% [markdown]
# # Draw the pair plot using sns for mpg, weight,orign and with hue origin, set the size to 4 ?

# %%
sns.pairplot(data,hue='origin')

# %%
c=['mpg','weight','origin']
sns.set(style="ticks",palette="Set2")
sns.pairplot(data,vars=c,hue="origin",height=4)

# %% [markdown]
# # identify name where acceleration is greater than 15 and horsepower less than 170 ?

# %%
#convert the horsepower column to numeric values
data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')
#filter the dataframe based on the conditions
filtered_data=data[(data['acceleration']>15)&(data['horsepower']<170)]
#display the name column of the filtered data frame
filtered_data['name']
# Out:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object

# %% [markdown]
# # Identify how many types of  cylinder vehicles you have ?

# %%
cylinders_count=data["cylinders"].value_counts()
cylinders_count
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %% [markdown]
# # how many vehicles in every  model_year ?

# %%
vehicles_count=data.groupby('model_year').size()
vehicles_count=pd.DataFrame(vehicles_count,columns=['count'])
vehicles_count
# Out:
#             count
# model_year
# 70             29
# 71             28
# 72             28
# 73             40
# 74             27
# 75             30
# 76             34
# 77             28
# 78             36
# 79             29
# 80             29
# 81             29
# 82             31
